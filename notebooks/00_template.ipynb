# %% [markdown]
# # Template: Data Analysis Notebook
#
# This is a template notebook demonstrating the ETL (Extract-Transform-Load) workflow.
#
# **Purpose**: [Describe what this notebook does]
#
# **Input**: `data/raw/[your_input_file]`
#
# **Output**: `data/output/[your_output_file].csv`

# %% [markdown]
# ## Setup
#
# Import required libraries and set up the environment.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Set visualization style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 1. Extract: Load Raw Data
#
# Load data from the `data/raw/` directory.

# %%
# Define paths
raw_data_path = Path('../data/raw')
processed_data_path = Path('../data/processed')
output_data_path = Path('../data/output')

# Load raw data
# Example: df = pd.read_csv(raw_data_path / 'your_file.csv')
# df = pd.read_csv(raw_data_path / 'data.csv')

print("Data loaded successfully")
# df.head()

# %% [markdown]
# ## 2. Explore Data
#
# Understand the structure and content of the data.

# %%
# Check data shape
# print(f"Data shape: {df.shape}")

# Check data types
# df.info()

# Summary statistics
# df.describe()

# %%
# Check for missing values
# df.isnull().sum()

# %% [markdown]
# ## 3. Transform: Clean and Process Data
#
# Clean, transform, and aggregate the data as needed.

# %%
# Example transformations:

# Handle missing values
# df_clean = df.dropna()
# df_clean = df.fillna(0)

# Convert data types
# df_clean['date'] = pd.to_datetime(df_clean['date'])

# Filter data
# df_filtered = df_clean[df_clean['value'] > 0]

# Create new columns
# df_clean['new_column'] = df_clean['column1'] * df_clean['column2']

print("Data transformation completed")

# %% [markdown]
# ## 4. Aggregate Data
#
# Perform aggregations, grouping, or summarizations.

# %%
# Example aggregations:

# Group by and aggregate
# df_agg = df_clean.groupby('category').agg({
#     'value': ['mean', 'sum', 'count']
# }).reset_index()

# Pivot table
# df_pivot = df_clean.pivot_table(
#     index='category',
#     columns='type',
#     values='value',
#     aggfunc='mean'
# )

print("Data aggregation completed")

# %% [markdown]
# ## 5. Visualize (Optional)
#
# Create visualizations to understand the data better.

# %%
# Example visualizations:

# Line plot
# df_clean.plot(x='date', y='value', kind='line')
# plt.title('Trend over time')
# plt.show()

# Bar plot
# df_agg.plot(x='category', y='value', kind='bar')
# plt.title('Values by category')
# plt.show()

# Histogram
# df_clean['value'].hist(bins=30)
# plt.title('Distribution of values')
# plt.show()

# %% [markdown]
# ## 6. Load: Save Results
#
# Save processed data or final results to CSV files.

# %%
# Save intermediate processed data
# df_clean.to_csv(processed_data_path / 'processed_data.csv', index=False)
# print(f"Processed data saved to {processed_data_path / 'processed_data.csv'}")

# Save final output
# df_agg.to_csv(output_data_path / 'final_results.csv', index=False)
# print(f"Final results saved to {output_data_path / 'final_results.csv'}")

# %% [markdown]
# ## Summary
#
# Summarize what was accomplished in this notebook:
#
# - Loaded raw data from `data/raw/`
# - Performed data cleaning and transformation
# - Aggregated data as needed
# - Saved results to `data/output/`
#
# **Next steps**: [Describe what should be done next]
